# %%
#chapter5 exercise-1
sum = 0
count = 0
avg = 0
num = ''
while(num != 'done'):
    try:
        num = input("Enter a number: ")
        
        if num == 'done':
            if count > 0:
                avg = sum/count
            print('Total: ', sum, ' Count: ', count, ' Average: ', avg)
        else:
            sum = sum + float(num)
            count += 1
    except:
        print('Invalid input')
        continue
# Out:
# Enter a number: 44
# Enter a number: 66
# Enter a number: 33
# Enter a number: 22
# Enter a number: 88
# Enter a number: done
# Total:  253.0  Count:  5  Average:  50.6

# %%
#chapter5 exercise-2
count=0
total=0
number=list()
value = ''
listV = []

while value != 'done':
    try:
        value = input('Enter a number: ')
        
        if value == 'done':
            print('Max: ', max(listV), ' Min: ', min(listV))
        else:
            listV.append((value))
    except:
        print('Invalid input')
        continue
# Out:
# Enter a number: 33
# Enter a number: 66
# Enter a number: 55
# Enter a number: 88
# Enter a number: 99
# Enter a number: done
# Max:  99  Min:  33

# %%
#chapter6 exercise-5
str='X-DSPAM-Confidence: 0.8475'
pos= str.find(':')   
new= str[pos+1:]             
result= float(new)           
print(result)
# Out:
# 0.8475

# %%
#chapter7 exercise-2
fname = input("Enter file name: ")
if len(fname) == 0:  
    fname = 'mbox.txt'
fh = open(fname)
count = 0
tot = 0
ans = 0
for line in fh:
    if not line.startswith("X-DSPAM-Confidence:") : continue
    count = count + 1
    num = float(line[21:])
    tot = num + tot
ans = tot / count
print ("Average spam confidence:", ans)
# Out:
# Enter file name: mbox.txt
# Average spam confidence: 0.8941280467445736

# %%
#Chapter8 exercise-4
fname = input('Enter file name: ')
fhand = open(fname)
lt = list()                       
for line in fhand:                 
    words= line.rstrip().split()    
    for element in words:               
        if element in lt:         
            continue               
        else :                     
            lt.append(element)    
lt.sort()                       
print ("words captured are:",lt)
# Out:
# Enter file name: romeo.txt
# words captured are: ['Arise', 'But', 'It', 'Juliet', 'Who', 'already', 'and', 'breaks', 'east', 'envious', 'fair', 'grief', 'is', 'kill', 'light', 'moon', 'pale', 'sick', 'soft', 'sun', 'the', 'through', 'what', 'window', 'with', 'yonder']

# %%
#chapter8 exercise-5
fname = input('Enter file name: ')

try:
    fhandle = open(fname)
except:
    print('File cannot be opened')
    exit()
names = []
for line in fhandle:
    line = line.rstrip()
    if not line.startswith('From '): continue
    words = line.split()
    if len(words) == 0: continue
    names.append(words[1])
    
count = 0
fhandle = open(fname)
for line in fhandle:
    line = line.rstrip()
    if not line.startswith('From '): continue
    count += 1

print('\n'.join(names), f'\n\nThere were {count} lines with \'From \' as the first word.')
# Out:
# Enter file name: mbox.txt
# stephen.marquard@uct.ac.za
# louis@media.berkeley.edu
# zqian@umich.edu
# rjlowe@iupui.edu
# zqian@umich.edu
# rjlowe@iupui.edu
# cwen@iupui.edu
# cwen@iupui.edu
# gsilver@umich.edu
# gsilver@umich.edu
# zqian@umich.edu
# gsilver@umich.edu
# wagnermr@iupui.edu
# zqian@umich.edu
# antranig@caret.cam.ac.uk
# gopal.ramasammycook@gmail.com
# david.horwitz@uct.ac.za
# david.horwitz@uct.ac.za
# david.horwitz@uct.ac.za
# david.horwitz@uct.ac.za
# stephen.marquard@uct.ac.za
# louis@media.berkeley.edu
# louis@media.berkeley.edu
# ray@media.berkeley.edu
# cwen@iupui.edu
# cwen@iupui.edu
# cwen@iupui.edu
# ray@media.berkeley.edu
# cwen@iupui.edu
# zqian@umich.edu
# cwen@iupui.edu
# zqian@umich.edu
# zqian@umich.edu
# zqian@umich.edu
# mmmay@indiana.edu
# cwen@iupui.edu
# zqian@umich.edu
# zqian@umich.edu
# zqian@umich.edu
# cwen@iupui.edu
# zqian@umich.edu
# cwen@iupui.edu
# ray@media.berkeley.edu
# zqian@umich.edu
# zqian@umich.edu
# zqian@umich.edu
# ...

# %%
#chapter9 exercise-4
fname = input('Enter file name: ')

try:
    fhandle = open(fname)
except:
    print('File cannot be opened')
    exit()
    
users = {}
for line in fhandle:
    if not line.startswith('From '): continue
    line = line.rstrip()
    words = line.split()
    if len(words) == 0: continue
    users[words[1]] = users.get(words[1], 0) + 1

keyMax = ''
maxValue = 0
for varKey in users:
    if keyMax != '' and users[varKey] < maxValue: continue
    maxValue = users[varKey]
    keyMax = varKey
print(f'User with most messages in the file: {keyMax} {users[keyMax]}')
# Out:
# Enter file name: mbox.txt
# User with most messages in the file: zqian@umich.edu 195

# %%
#chapter9 exercise-5
fname = input("Enter a file name: ")
lines = [line.strip('\n') 
for line in open(fname, 'r')
if line.startswith("From ")]
fromdict = {}
for line in lines:
    line = line.split()
    email = line[1]
    domain = email.split("@")[1]
    fromdict[domain] = fromdict.get(domain, 0) + 1
print (fromdict)
# Out:
# Enter a file name: mbox.txt
# {'uct.ac.za': 96, 'media.berkeley.edu': 56, 'umich.edu': 491, 'iupui.edu': 536, 'caret.cam.ac.uk': 157, 'gmail.com': 25, 'indiana.edu': 178, 'et.gatech.edu': 17, 'vt.edu': 110, 'lancaster.ac.uk': 14, 'ucdavis.edu': 1, 'ufp.pt': 28, 'txstate.edu': 17, 'stanford.edu': 12, 'whitman.edu': 17, 'rsmart.com': 8, 'fhda.edu': 1, 'bu.edu': 14, 'unicon.net': 9, 'loi.nl': 9, 'utoronto.ca': 1}

# %%
#chapter10 exercise-2
fname = input("Enter a file name: ")
llist = [line.strip("\n") 
for line in open(fname, 'r')
if line.startswith("From ")]
hourhistogram = {}
tuplelist = []

for line in llist:
    time = line.split()[5]
    hour = time.split(":")[0]
    hourhistogram[hour] = hourhistogram.get(hour, 0) + 1
for key in hour_histogram:
    tuplelist.append((key, hourhistogram[key]))
sortedtuplelist = sorted(tuplelist)
for item in sortedtuplelist:
print (item[0], item[1])
# Out:
# Enter a file name: mbox.txt
# 00 23
# 01 10
# 02 11
# 03 19
# 04 23
# 05 10
# 06 45
# 07 42
# 08 72
# 09 166
# 10 198
# 11 154
# 12 108
# 13 114
# 14 150
# 15 152
# 16 181
# 17 97
# 18 58
# 19 46
# 20 36
# 21 36
# 22 28
# 23 18

# %%
#chapter10-exercise-3
import string
fname = input('Enter file name: ')
try:
    fhandle = open(fname)
except:
    print('File cannot be opened')
    exit()
    
letters = {}
for line in fhandle:
    if line == '\n': continue
    line = line.rstrip()
    line = line.translate({ord(i): None for i in '0123456789 —' + string.punctuation})   
    line = line.lower()
    for letter in line:
        letters[letter] = letters.get(letter, 0) + 1
listLetters = []
for letter in letters:
    listLetters.append(letter)
listLetters.sort()
for l in listLetters:
    print(f'{l} {letters[l]}')
print('\n\n')
totalLetters = 0
for value in letters.values():
    totalLetters += value
freqList = {}
for letter in listLetters:
    freqList[letter] = (letters[letter]/totalLetters)*100

for l in freqList:
    print(f'{l} {freqList[l]:.2f}%')
# Out:
# Enter file name: romeo.txt
# a 11
# b 2
# c 1
# d 6
# e 12
# f 3
# g 3
# h 9
# i 14
# j 1
# k 3
# l 6
# m 1
# n 9
# o 8
# p 1
# r 7
# s 11
# t 12
# u 6
# v 1
# w 5
# y 2
#
#
#
# a 8.21%
# b 1.49%
# c 0.75%
# d 4.48%
# e 8.96%
# f 2.24%
# g 2.24%
# h 6.72%
# i 10.45%
# j 0.75%
# k 2.24%
# l 4.48%
# m 0.75%
# n 6.72%
# o 5.97%
# p 0.75%
# r 5.22%
# s 8.21%
# t 8.96%
# u 4.48%
# v 0.75%
# w 3.73%
# y 1.49%
